# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# # 2.4 Wedding Planner
# In this lab you will build a multi-agent wedding planner.
#
# > Note: This lab has been updated since filming to make the agent performance more robust to errors and to limit run time. In particular: 1) added error handling for MCP failures, 2) limited the number of searches. It's worth noting that, where possible, tool errors should be returned to the agent rather than failing so that the agent can adjust its invocation and try again.

# %% [markdown]
# ## Setup Tools

# %%
import asyncio

from langchain_mcp_adapters.client import MultiServerMCPClient
from mcp.shared.exceptions import McpError
from mcp.types import CallToolResult, TextContent

RETRYABLE_MCP_CODES = {-32603}

class RetryMCPInterceptor:
    """Intercept MCP tool calls: retry transient failures, surface all errors gracefully.

    - Retryable McpError codes (e.g. -32603): retry with exponential backoff.
    - Non-retryable McpError codes (e.g. -32602): return error message immediately.
    - Any other exception (fetch failed, network errors, etc.): retry then return error message.
    """

    def __init__(self, max_retries: int = 3):
        self.max_retries = max_retries

    async def __call__(self, request, handler):
        last_error = None
        for attempt in range(self.max_retries):
            try:
                return await handler(request)
            except McpError as exc:
                last_error = exc
                print(f"[MCP interceptor] {type(exc).__name__} on {request.name} "
                      f"(code {exc.error.code}, attempt {attempt+1}/{self.max_retries}): {exc}")
                if exc.error.code not in RETRYABLE_MCP_CODES:
                    return CallToolResult(
                        content=[TextContent(type="text", text=f"Tool call failed (non-retryable): {exc}")],
                        isError=False,
                    )
            except Exception as exc:
                last_error = exc
                print(f"[MCP interceptor] {type(exc).__name__} on {request.name} "
                      f"(attempt {attempt+1}/{self.max_retries}): {exc}")

            if attempt < self.max_retries - 1:
                await asyncio.sleep(2 ** attempt)

        print(f"[MCP interceptor] all {self.max_retries} retries exhausted for {request.name}")
        return CallToolResult(
            content=[TextContent(type="text", text=f"Tool call failed after {self.max_retries} attempts: {last_error}")],
            isError=False,
        )

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    },
    tool_interceptors=[RetryMCPInterceptor()],
)

tools = await client.get_tools()

# %%
from typing import Dict, Any
from tavily import TavilyClient
from langchain.tools import tool

tavily_client = TavilyClient()

@tool
def web_search(query: str, search_number: int, max_search_number: int) -> Dict[str, Any]:
    """Search the web for information. You must track your search count by providing
    search_number (starting at 1) and max_search_number on every call.
    Queries must use only plain text characters. Do not use accented or special characters     
      (e.g., use 'capacite' instead of 'capacité').
    """
    if search_number > max_search_number:
        return {"message": "Search limit reached. Please summarize your findings and provide your final answer."}
    try:
        return tavily_client.search(query)
    except Exception as e:
        return {"error": str(e)}

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

@tool
def query_playlist_db(query: str) -> str:

    """Query the database for playlist information"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error querying database: {e}"
# Out:
# /var/folders/rp/71fd1xts72s4xqq6gpvgm21c0000gn/T/ipykernel_81806/2549610831.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.utilities import SQLDatabase

# %% [markdown]
# ## Create State

# %%
from langchain.agents import AgentState

class WeddingState(AgentState):
    origin: str
    destination: str
    guest_count: str
    genre: str

# %% [markdown]
# ## Create Subagents

# %%
from langchain.agents import create_agent

# Travel agent
travel_agent = create_agent(
    model="gpt-5-nano",
    tools=tools,
    system_prompt="""
    You are a travel agent. Search for flights to the desired destination wedding location.
    You are not allowed to ask any more follow up questions, you must find the best flight options based on the following criteria:
    - Price (lowest, economy class)
    - Duration (shortest)
    - Date (time of year which you believe is best for a wedding at this location)
    To make things easy, only look for one ticket, one way.
    You may need to make multiple searches to iteratively find the best options.
    You will be given no extra information, only the origin and destination. It is your job to think critically about the best options.
    If the MCP tool fails, returns malformed output, or does not give you usable flight results, try the tool again.
    Once you have found the best options, let the user know your shortlist of options.
    """
)

# %%
# Venue agent
venue_agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search],
    system_prompt="""
    You are a venue specialist. Search for venues in the desired location, and with the desired capacity.
    You are not allowed to ask any more follow up questions, you must find the best venue options based on the following criteria:
    - Price (lowest)
    - Capacity (exact match)
    - Reviews (highest)
    You may need to make multiple searches to iteratively find the best options. 
    You have a suggested limit of 12 web searches. Count every web_search call you make.
    After 12 searches, you should stop searching and summarize the best options you have
    found so far.
    """
)

# %%
# Playlist agent
playlist_agent = create_agent(
    model="gpt-5-nano",
    tools=[query_playlist_db],
    system_prompt="""
    You are a playlist specialist. Query the sql database and curate the perfect playlist for a wedding given a genre.
    Once you have your playlist, calculate the total duration and cost of the playlist, each song has an associated price.
    If you run into errors when querying the database, try to fix them by making changes to the query.
    Do not come back empty handed, keep trying to query the db until you find a list of songs.

    This is a SQLite database. Before writing any data queries, first discover the schema.
    """
)

# %% [markdown]
# ## Main Coordinator

# %%
from langchain.tools import ToolRuntime
from langchain.messages import HumanMessage, ToolMessage
from langgraph.types import Command

@tool
async def search_flights(runtime: ToolRuntime) -> str:
    """Travel agent searches for flights to the desired destination wedding location."""
    origin = runtime.state["origin"]
    destination = runtime.state["destination"]
    response = await travel_agent.ainvoke({"messages": [HumanMessage(content=f"Find flights from {origin} to {destination}")]})
    return response['messages'][-1].content

@tool
def search_venues(runtime: ToolRuntime) -> str:
    """Venue agent chooses the best venue for the given location and capacity."""
    destination = runtime.state["destination"]
    capacity = runtime.state["guest_count"]
    query = f"Find wedding venues in {destination} for {capacity} guests"
    response = venue_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def suggest_playlist(runtime: ToolRuntime) -> str:
    """Playlist agent curates the perfect playlist for the given genre."""
    genre = runtime.state["genre"]
    query = f"Find {genre} tracks for wedding playlist"
    response = playlist_agent.invoke({"messages": [HumanMessage(content=query)]})
    return response['messages'][-1].content

@tool
def update_state(origin: str, destination: str, guest_count: str, genre: str, runtime: ToolRuntime) -> str:
    """Update the state when you know all of the values: origin, destination, guest_count, genre. 
    This tool must be called alone, without any other tool calls. It must complete and return to make,
    the information available to other tools."""
    return Command(update={
        "origin": origin, 
        "destination": destination, 
        "guest_count": guest_count, 
        "genre": genre, 
        "messages": [ToolMessage("Successfully updated state", tool_call_id=runtime.tool_call_id)]}
        )

# %%
from langchain.agents import create_agent

coordinator = create_agent(
    model="gpt-5-nano",
    tools=[search_flights, search_venues, suggest_playlist, update_state],
    state_schema=WeddingState,
    system_prompt="""
    You are a wedding coordinator. 
    First find all the information you need to update the state. When you have the information, update the state.
    Once that has completed and returned, you can delegate the tasks 
    to your specialists for flights, venues, and playlists.
    Once you have received their answers, coordinate the perfect wedding for me.
    """
)

# %% [markdown]
# ## Test

# %%
from langchain.messages import HumanMessage

response = await coordinator.ainvoke(
    {
        "messages": [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre")],
    },
    config={"tags": ["WP"], "recursion_limit": 40},  #tag traces to make them easy to find in Langsmith. Increase number of steps the agent can take to 40.
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'destination': 'Paris',
#  'genre': 'jazz',
#  'guest_count': '100',
#  'messages': [HumanMessage(content="I'm from London and I'd like a wedding in Paris for 100 guests, jazz-genre", additional_kwargs={}, response_metadata={}, id='da4ae41b-4b56-4b8c-9ded-1430487f7cda'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 485, 'prompt_tokens': 336, 'total_tokens': 821, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHKkdafinicgJJr67bS6XZM1DJ14V', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0412f-d91b-7d61-9770-8a8a9ea4bfda-0', tool_calls=[{'name': 'update_state', 'args': {'origin': 'London', 'destination': 'Paris', 'guest_count': '100', 'genre': 'jazz'}, 'id': 'call_Zm3RW9PIfNLlfCpm2jBCjpZk', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 336, 'output_tokens': 485, 'total_tokens': 821, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}}),
#               ToolMessage(content='Successfully updated state', name='update_state', id='4fe638d8-4d8d-4f90-8d13-d6bf4bfaa5f6', tool_call_id='call_Zm3RW9PIfNLlfCpm2jBCjpZk'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 381, 'total_tokens': 395, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHKkhHoGVlVjo5KwSZ08Y4pRpGLlr', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a0412f-ebe3-7781-8c76-72d2f94c63a3-0', tool_calls=[{'name': 'search_flights', 'args': {}, 'id': 'call_JFz0jbieSKjCYVHqqlHb42sL', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 381, 'output_tokens': 14, 'total_tokens': 395, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Here are the top one-way economy flight options from London to Paris, picked for price, duration, and a wedding-season friendly date (late spring to early summer is ideal for a Paris wedding).\n\nCheapest option overall\n- Route: LTN → CDG\n- Times & duration: 15 May 06:05 → 08:30 (2h25m)\n- Cabin: Economy\n- Price: 64 EUR\n- Booking: https://kiwi.com/u/vp34dj\n\nShortest-duration option(s) (minimum flight time in these results)\n- Route: LGW → CDG\n- Times & duration: 15 May 09:55 → 12:10 (1h20m, 4500s)\n- Cabin: Economy\n- Price: 84 EUR\n- Booking: https://kiwi.com/u/yrhmq2\n\nWedding-season-friendly option (June date, still great value)\n- Route: LTN → CDG\n- Times & duration: 05 Jun 06:05 → 08:30 (2h25m)\n- Cabin: Economy\n- Price: 66 EUR\n- Booking: https://kiwi.com/u/zhpnzrn\n\nNotable other good value option (also direct, reasonable time)\n- Route: LGW → CDG\n- Times & duration: 15 May 16:30 → 18:50 (1h20m)\n- Cabin: Economy\n- Price: 74 EUR\n- Booking: https://kiwi.com/u/4y9vdn\n\nRecommendation\n- For a wedding trip in Paris, the June option (05 Jun) is a strong pick: it’s affordable, direct, and sits in peak wedding-season timing. If you’re flexible on exact date, this is a great balance of price and convenience.\n\nNice trip tip\n- Paris is famously called the City of Light. Fun fact: spring and early summer in Paris offer long, pleasant evenings perfect for wedding-related events and strolls along the Seine. Have a wonderful trip!', name='search_flights', id='28eb600b-14eb-4b10-86b9-e8b19f54f4ff', tool_call_id='call_JFz0jbieSKjCYVHqqlHb42sL'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 829, 'total_tokens': 843, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHKlhV2AcytP1hHGTUCIQ46DMYcGV', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a04130-de52-7472-a5ea-9914de09cdea-0', tool_calls=[{'name': 'search_venues', 'args': {}, 'id': 'call_XPm5CdJ0W9BlpoFY4lFBfbed', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 829, 'output_tokens': 14, 'total_tokens': 843, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content='Here are Paris wedding venues that can accommodate around 100 guests (capacity listed as max 100 or 0-100 where shown). Ranked by the strength of venue quality and available price info, with notes on price and reviews from the sources.\n\n1) Le Georges (Paris)\n- Capacity: Up to 100 guests\n- Price (approx): Starting at about €15,000 (as cited by a venue round-up)\n- Location: Place Georges-Pompidou, 4th arrondissement\n- Why consider: Modern design with panoramic views of Paris; intimate yet stylish setting\n- Source: Lejolistudio article listing capacity and starting price\n- Link: https://www.lejolistudio.com/wedding-blog/10-most-unique-wedding-venues-paris\n\n2) The Peninsula Paris (Luxury hotel)\n- Capacity: Up to 100 guests\n- Price: Not shown on the page, but as a luxury hotel, typically at the higher end\n- Location: 19 Avenue Kléber, 75016 Paris\n- Why consider: World-class service, elegant ballrooms, highly rated with strong guest reviews\n- Source: The Peninsula Paris wedding/events page\n- Link: https://www.peninsula.com/en/paris/events/hotel-wedding-venues\n\n3) Hôtel Le Crillon (Palace hotel)\n- Capacity: 0-100 guests (can host up to 100 for ceremonies/receptions)\n- Price: High (luxury, iconic venue)\n- Location: 10 Place de la Concorde, Paris\n- Why consider: Historic, opulent interiors; prestigious addresses; strong overall guest reviews\n- Source: The Paris Officiant venue listing for Crillon (capacity range) \n- Link: https://theparisofficiant.com/paris-wedding-venue\n\n4) Musée Rodin (Museum venue)\n- Capacity: 0-100 guests (private spaces available for up to 100)\n- Price: Varies by space and package (noted as a strong venue option)\n- Location: 79 Rue de Varenne, 75007 Paris (near Invalides)\n- Why consider: Iconic sculpture gardens and refined interiors; intimate setting with museum ambiance\n- Source: The Paris Officiant list of ceremony locations including Musée Rodin\n- Link: https://theparisofficiant.com/paris-wedding-venue\n\nNotes\n- These options are pulled from sources that explicitly indicate max capacities around 100 guests. If you want strictly “exactly 100” in all wording, these venues offer 100-capacity as a ceiling or stated max, allowing a 100-person guest list.\n- Prices vary by season, guest count, and package; the le Georges option includes a stated starting price in a venue round-up, while Peninsula/Crillon are premium options with higher typical price brackets.\n- If you’d like, I can continue searching for additional 100-capacity venues in Paris and compare them on price, exact capacity wording, and latest guest-review highlights.', name='search_venues', id='3b034d03-0c1b-4447-b1f5-28221726226b', tool_call_id='call_XPm5CdJ0W9BlpoFY4lFBfbed'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 1476, 'total_tokens': 1490, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHKmS6fPj8J184ZXmjau9rwi1ZWsV', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a04131-97ea-7cf0-8477-82bede839a9e-0', tool_calls=[{'name': 'suggest_playlist', 'args': {}, 'id': 'call_4CICuZDXMuO2BRYmKA5zg2B1', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1476, 'output_tokens': 14, 'total_tokens': 1490, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#               ToolMessage(content="Here’s a wedding-friendly jazz playlist curated from the jazz tracks in the database. It blends Brazilian bossa nova vibes, classic swing, and smooth jazz for a romantic yet upbeat flow. Total duration is about 40 minutes, and total cost is $14.85.\n\n1) Desafinado — Antônio Carlos Jobim — Album: Warner 25 Anos — Duration: 3:05 — Price: $0.99\n2) Samba De Uma Nota Só (One Note Samba) — Antônio Carlos Jobim — Album: Warner 25 Anos — Duration: 2:17 — Price: $0.99\n3) Fotografia — Antônio Carlos Jobim — Album: Warner 25 Anos — Duration: 2:09 — Price: $0.99\n4) Outra Vez — Antônio Carlos Jobim — Album: Warner 25 Anos — Duration: 2:06 — Price: $0.99\n5) Angela — Antônio Carlos Jobim — Album: Warner 25 Anos — Duration: 2:49 — Price: $0.99\n6) Por Causa De Você — Antônio Carlos Jobim — Album: Warner 25 Anos — Duration: 2:50 — Price: $0.99\n7) Se Todos Fossem Iguais A Você (Instrumental) — Antônio Carlos Jobim — Album: Warner 25 Anos — Duration: 2:15 — Price: $0.99\n8) Lament — Miles Davis — Album: Miles Ahead — Duration: 2:14 — Price: $0.99\n9) The Meaning Of The Blues — Miles Davis — Album: Miles Ahead — Duration: 2:49 — Price: $0.99\n10) Generique — Miles Davis — Album: The Essential Miles Davis [Disc 1] — Duration: 2:49 — Price: $0.99\n11) Overtime — Gene Krupa — Album: Up An' Atom — Duration: 2:43 — Price: $0.99\n12) Coronation Drop — Gene Krupa — Album: Up An' Atom — Duration: 2:56 — Price: $0.99\n13) Up An' Atom — Gene Krupa — Album: Up An' Atom — Duration: 2:59 — Price: $0.99\n14) Opus No.1 — Gene Krupa — Album: Up An' Atom — Duration: 2:59 — Price: $0.99\n15) Leave Us Leap — Gene Krupa — Album: Up An' Atom — Duration: 3:02 — Price: $0.99\n\nTotals:\n- Total duration: 40 minutes 6 seconds (2,405.61 seconds)\n- Total cost: $14.85\n\nWould you like me to adjust the vibe (more ballads, more swing, or closer to Brazilian jazz) or extend the playlist with additional tracks?", name='suggest_playlist', id='033aafff-a530-481f-a29c-548018c6fd05', tool_call_id='call_4CICuZDXMuO2BRYmKA5zg2B1'),
#               AIMessage(content='Great news so far. Here’s a coordinated plan based on the latest info from flights, venues, and a jazz playlist. I’ve kept the options flexible so we can lock things in smoothly.\n\nWhat I have for you so far\n- Origin: London\n- Destination: Paris\n- Guests: ~100\n- Music/style: Jazz\n\nFlights (from London to Paris)\nRecommendation: June date is the best balance of price, direct options, and Paris wedding season timing.\n- Best option (June 5): LTN → CDG, 05 Jun 06:05 → 08:30, 2h25m, Economy, ~66 EUR\n  - Direct flight, affordable, good for a wedding weekend arrival\n  - Booking link: 05 Jun option\n- Shortest duration option: LGW → CDG, 15 May 09:55 → 12:10, 1h20m, Economy, ~84 EUR\n- Other solid choice (May 15): LTN → CDG, 15 May 06:05 → 08:30, 2h25m, Economy, ~64 EUR\n- Direct, reasonable time (May 15): LGW → CDG, 15 May 16:30 → 18:50, 1h20m, Economy, ~74 EUR\n\nVenues in Paris for ~100 guests\nNotes: All options can accommodate around 100 guests (capacity stated as up to 100 or 0-100). Prices vary by season and package.\n- Le Georges (Paris)\n  - Capacity: Up to 100\n  - Price: Starting ~€15,000\n  - Why consider: Modern design, panoramic city views, stylish, intimate feel\n  - Link: https://www.lejolistudio.com/wedding-blog/10-most-unique-wedding-venues-paris\n- The Peninsula Paris (luxury hotel)\n  - Capacity: Up to 100\n  - Price: Premium (not shown publicly)\n  - Why consider: World-class service, elegant ballrooms\n  - Link: https://www.peninsula.com/en/paris/events/hotel-wedding-venues\n- Hôtel Le Crillon (Palace hotel)\n  - Capacity: 0-100 (ceremony/reception for up to 100)\n  - Price: High (luxury)\n  - Why consider: Historic, iconic, opulent interiors\n  - Link: https://theparisofficiant.com/paris-wedding-venue\n- Musée Rodin (Museum venue)\n  - Capacity: 0-100 (private spaces for up to 100)\n  - Price: Varies by space and package\n  - Why consider: Iconic gardens, refined interiors, intimate ambiance\n  - Link: https://theparisofficiant.com/paris-wedding-venue\n\nPlaylist (current draft)\n- Jazz-forward vibe with a touch of Brazilian bossa nova and classic swing for a romantic yet upbeat flow\n- Tracks include: Desafinado, Samba De Uma Nota Só, Fotografia, Outra Vez, Angela, Por Causa De Você, Se Todos Fossem Iguais A Você (Instrumental), plus Miles Davis and Gene Krupa selections\n- Total approx. 40 minutes; current set is good for cocktail hour and background during dinner/dancing transitions\n- Want me to extend this into a full day plan (ceremony, cocktail, dinner, dancing) or tailor to more swing/ballads/Brazilian jazz?\n\nNext steps I can take for you (tell me which to proceed with)\n- Lock in a date and travel plan\n  - If you’re happy with the June 5 option, I can start arranging a group block for flights from London to Paris and hold seats for guests, plus look at hotel blocks near your chosen venue.\n  - If you’d prefer another date, I can compare May dates as backups and secure the best options.\n- Venue shortlist and tours\n  - I can reach out to the four venues above to check current availability for your exact date, get package details, and arrange site visits or virtual tours.\n  - Help compare packages (room rental, catering minimums, decor allowances, included services).\n- Music plan\n  - Create a full day-of playlist: pre-ceremony, ceremony processional, cocktail hour, dinner, dancing.\n  - Decide on the balance for swing vs. ballads vs. Brazilian jazz and whether you want live music for certain segments (e.g., a jazz trio for reception, ceremony violinist, etc.).\n- Budget and logistics\n  - I can draft a high-level budget (venue, catering, a/c, music, transport, decor) and timeline (60-90 days to bookings, 30 days to finalize contracts).\n  - Outline guest arrival/transfer flow (airport to hotel to venue) and potential hotel blocks with best proximity to venue.\n- Vendor coordination\n  - Once you pick a date and venue, I’ll coordinate catering, photography/ ...
#  'origin': 'London'}

# %%
print(response["messages"][-1].content)
# Out:
# Great news so far. Here’s a coordinated plan based on the latest info from flights, venues, and a jazz playlist. I’ve kept the options flexible so we can lock things in smoothly.
#
# What I have for you so far
# - Origin: London
# - Destination: Paris
# - Guests: ~100
# - Music/style: Jazz
#
# Flights (from London to Paris)
# Recommendation: June date is the best balance of price, direct options, and Paris wedding season timing.
# - Best option (June 5): LTN → CDG, 05 Jun 06:05 → 08:30, 2h25m, Economy, ~66 EUR
#   - Direct flight, affordable, good for a wedding weekend arrival
#   - Booking link: 05 Jun option
# - Shortest duration option: LGW → CDG, 15 May 09:55 → 12:10, 1h20m, Economy, ~84 EUR
# - Other solid choice (May 15): LTN → CDG, 15 May 06:05 → 08:30, 2h25m, Economy, ~64 EUR
# - Direct, reasonable time (May 15): LGW → CDG, 15 May 16:30 → 18:50, 1h20m, Economy, ~74 EUR
#
# Venues in Paris for ~100 guests
# Notes: All options can accommodate around 100 guests (capacity stated as up to 100 or 0-100). Prices vary by season and package.
# - Le Georges (Paris)
#   - Capacity: Up to 100
#   - Price: Starting ~€15,000
#   - Why consider: Modern design, panoramic city views, stylish, intimate feel
#   - Link: https://www.lejolistudio.com/wedding-blog/10-most-unique-wedding-venues-paris
# - The Peninsula Paris (luxury hotel)
#   - Capacity: Up to 100
#   - Price: Premium (not shown publicly)
#   - Why consider: World-class service, elegant ballrooms
#   - Link: https://www.peninsula.com/en/paris/events/hotel-wedding-venues
# - Hôtel Le Crillon (Palace hotel)
#   - Capacity: 0-100 (ceremony/reception for up to 100)
#   - Price: High (luxury)
#   - Why consider: Historic, iconic, opulent interiors
#   - Link: https://theparisofficiant.com/paris-wedding-venue
# - Musée Rodin (Museum venue)
#   - Capacity: 0-100 (private spaces for up to 100)
#   - Price: Varies by space and package
#   - Why consider: Iconic gardens, refined interiors, intimate ambiance
#   - Link: https://theparisofficiant.com/paris-wedding-venue
#
# Playlist (current draft)
# - Jazz-forward vibe with a touch of Brazilian bossa nova and classic swing for a romantic yet upbeat flow
# - Tracks include: Desafinado, Samba De Uma Nota Só, Fotografia, Outra Vez, Angela, Por Causa De Você, Se Todos Fossem Iguais A Você (Instrumental), plus Miles Davis and Gene Krupa selections
# - Total approx. 40 minutes; current set is good for cocktail hour and background during dinner/dancing transitions
# - Want me to extend this into a full day plan (ceremony, cocktail, dinner, dancing) or tailor to more swing/ballads/Brazilian jazz?
#
# Next steps I can take for you (tell me which to proceed with)
# - Lock in a date and travel plan
#   - If you’re happy with the June 5 option, I can start arranging a group block for flights from London to Paris and hold seats for guests, plus look at hotel blocks near your chosen venue.
#   - If you’d prefer another date, I can compare May dates as backups and secure the best options.
# - Venue shortlist and tours
#   - I can reach out to the four venues above to check current availability for your exact date, get package details, and arrange site visits or virtual tours.
#   - Help compare packages (room rental, catering minimums, decor allowances, included services).
# - Music plan
#   - Create a full day-of playlist: pre-ceremony, ceremony processional, cocktail hour, dinner, dancing.
#   - Decide on the balance for swing vs. ballads vs. Brazilian jazz and whether you want live music for certain segments (e.g., a jazz trio for reception, ceremony violinist, etc.).
# - Budget and logistics
#   - I can draft a high-level budget (venue, catering, a/c, music, transport, decor) and timeline (60-90 days to bookings, 30 days to finalize contracts).
#   - Outline guest arrival/transfer flow (airport to hotel to venue) and potential hotel blocks with best proximity to venue.
# - Vendor coordination
#   - Once you pick a date and venue, I’ll coordinate catering, photography/videography, florals, transport, and day-of coordinator if needed.
#
# Questions for you
# - Do you want to aim for the June 5 date, or would you prefer we lock a May date or a flexible weekend in late spring?
# - Which venue vibe appeals to you most: ultra-modern (Le Georges), classic luxury (Peninsula), historic opulence (Hôtel Le Crillon), or garden/artsy (Musée Rodin)?
# - What budget range should I target for the venue, catering, and wedding day services?
# - How formal do you want the ceremony and reception to feel (black-tie, semi-formal, relaxed chic)?
# - Any must-haves for music (live musician in the ceremony, DJ for dancing, specific songs, or culturally meaningful pieces)?
# - Any dietary restrictions or special guest accommodations to consider?
#
# If you’re ready, I can start the bookings and vendor outreach right away. Tell me which date and the top 2–3 venue picks, and I’ll proceed with parallel actions (flights group block, venue inquiries, and initial playlist expansion) to pace everything efficiently.

# %% [markdown]
# link to trace: https://smith.langchain.com/public/7b5fe668-d3e3-4af4-b513-a8cacc0c9e84/r
