# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In this sci‑fi setting, the capital of The Moon is Lunaris Prime.
#
# - Location: Built on the sunlit rim of Shackleton Crater, near the lunar south pole. A city perched at the edge where near-constant solar windows drive energy and life.
# - Government: Seat of the Lunar Directorate, a representative body that governs science, resources, and civil affairs for the Moon and its settlements.
# - Architecture: A ring of domed districts encircling the crater, using lunar ice for life support, basalt for construction, and shimmering glass and pale metals. Inside are vast hover-ramps, gravity-adjusted promenades, and subterranean hubs protected from micrometeoroids.
# - Economy: Power hub for the Moon due to giant solar farms; major player in helium-3 mining and water-ice extraction; logistics and research services orbit-to-surface.
# - Landmarks: The Council Spire (government seat), Echo Dome (arts and culture), and the Ice Garden (public park carved from frozen regolith).
# - Culture: A cosmopolitan blend of scientists, engineers, miners, and artists; annual First Light Festival celebrates solar reactivation after long lunar nights.
# - Transportation: Surface mag-rails and tramways connect to remote outposts; a busy spaceport, Aurora Port, handles Earth-to-Moon traffic and freight.
#
# If you’d like, I can tailor Lunaris Prime’s history, notable residents, or a day-in-the-life vignette set there.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'moon.png', 'type': 'image/png', 'size': 358916, 'content': <memory at 0x1121cb340>, 'last_modified': datetime.datetime(2026, 8, 25, 5, 4, 24, 347000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# This appears to be Luminara, the capital city of a crater-world civilization that thrives in a harsh, sun-scarred landscape. It’s a place where glass towers claw at the sky and the night sparkles with bioluminescent life, all built to make light and heat their allies.
#
# Snapshot
# - Location and vibe: A desert-crater world with jagged basalt cliffs. A luminous city rises in the crater’s heart, anchored by a spine of towering structures that glows with blue and teal energy.
# - Architecture: Sinuous glass and dark alloy towers linked by skybridges. Buildings drill upward like crystalline stalagmites, their surfaces etched with solar-collectors and photonic courtyards. The city feels both dungeon-cavernous and cathedral-like, designed to trap and reflect light.
# - Energy and tech: Photonic grids, compact fusion cores, and a network of magnetic transit lines. There are “blue lakes” of energy—glow-globules pumped from deep aquifers and cooled with mineral lattices—that bathe corridors and plazas in cool, ghostly light.
# - Government and society: A meritocratic-conclave system that blends technocrats, poets, and engineers. Decisions emerge from the Council of Luminants, a rotating leadership drawn from districts with checks and balances overseen by public consensus councils.
# - Culture and daily life: A society that treats light as a resource, art as infrastructure, and conversation as energy. Festivals center on light shows, reflective textiles, and sound sculptures that respond to ambient glow.
# - Economy: High-tech manufacturing, energy export, and a vibrant trade in rare minerals and optical materials. The city doubles as a diplomatic hub with orbital and interplanetary connections.
# - Notable districts and landmarks:
#   - The Radiant Spine: The central corridor of tower-palaces that house government, research, and ceremonial spaces. Bridges glow with a soft cyan light at night.
#   - The Glass Market: A labyrinth of glass-fronted stalls selling photonic artifacts, solar fabrics, and mood-lume beverages.
#   - Verdant Rims: Vertical gardens clinging to cliff faces and lowland terraces that help regulate climate and provide food.
#   - Echoes Den: A cavernous concert hall network where sound is sculpted by mineral walls—music modifies the city’s resonance.
#   - Beacon of New Dawn: A colossal beacon atop the highest tower, used for long-range visibility and ceremonial events.
# - Current mood: A peaceful moment before a diplomatic summit and a subtle tension as new energy tech threatens old power balances.
#
# Deeper lore (at a glance)
# - History: Luminara grew from a mining outpost that learned to convert heat and mineral byproducts into light. A century of political evolution created the Conclave of Luminants, which blends governance with scientific and artistic councils. The city’s identity is the light it generates—and what it can illuminate for others.
# - Government: The Council of Luminants rotates leadership monthly, ensuring no single patron company or district dominates. Decisions are debated in public chambers, then implemented through the City Engine—a shared computational backbone that synchronizes infrastructure and energy flows.
# - Technology emphasis: Energy capture from solar-thermal collectors and depth-energy wells; photonic manufacturing; precision gravity rails for safe transit; adaptive habitat domes for comfortable living in an otherwise harsh climate.
# - Daily life: Residents wear reflective textiles that modulate heat absorption and mood-light colors. Street food blends local mineral flavors with light-infused sauces. Public spaces are designed to bloom after sunset, when the city’s energy grid makes night as bright as day.
#
# If you want, I can tailor Luminara to your taste:
# - Rename it and its world (e.g., a water-poor world with wind towers, or a moon-like satellite city).
# - Change the governing setup (from a council to a technocratic monarchy, or a guild-based democracy).
# - Add a current plot hook (a successor to the Beacon, a contested resource, a political scandal, or a visitor from another star system).
#
# Would you like a short scene set in Luminara, or a map outline with district-by-district geography for a story or game?

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████| 50/50 [00:05<00:00,  9.54it/s]
# Done.

# %%
agent = create_agent(
    model='gpt-audio',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# I can certainly craft a poem about dogs for you. Here it is:
#
# With fur so soft and eyes so bright,
# In morning’s glow or fading light,
# The faithful friend, forever near,
# A wagging tail, dispelling fear.
#
# They leap and bound through fields of green,
# Such joy in motion, often seen,
# With playful barks and cozy paws,
# They warm the heart with gentle cause.
#
# Through every walk, through rain or sun,
# A dog’s good cheer is never done,
# For in their eyes, a love so true,
# A bond unbreakable with you.
