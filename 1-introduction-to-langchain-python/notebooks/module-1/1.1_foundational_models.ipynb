# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country or city and has no government or capital. \n\nIf you were just playing with words, the capital (uppercase) letter in the word “Moon” is M.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 693, 'prompt_tokens': 13, 'total_tokens': 706, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EGpdWvWl731LpcS9AJ0rBQmzg70PS', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a03a0e-d531-7992-96af-756d81daaa0d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 693, 'total_tokens': 706, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or city and has no government or capital.
#
# If you were just playing with words, the capital (uppercase) letter in the word “Moon” is M.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-EGpdWvWl731LpcS9AJ0rBQmzg70PS',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 693,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 640,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cache_write_tokens': None,
#                                            'cached_tokens': 0},
#                  'total_tokens': 706}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital.
#
# If you meant something else:
# - Capital letter: the word “Moon” starts with M.
# - In fiction, capitals vary by story (some authors have Lunapolis, Lunaria, etc.). If you have a specific book or universe in mind, tell me and I’ll name it.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-6")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital city. It has no permanent human settlements or government. The Moon is currently uninhabited, though it has been visited by Apollo astronauts and explored by robotic spacecraft. Various countries and private organizations have discussed plans for future lunar bases, but none exist yet.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# [{'type': 'text', 'text': 'The Moon does not have a capital because it has no government, no countries, and no permanent human population. Under international law, specifically the **Outer Space Treaty of 1967**, no nation can claim sovereignty over the Moon or any other celestial body.\n\nWhile there are various research bases and landers planned or currently on the surface, they are operated by individual space agencies (like NASA, CNSA, or ISRO) or private companies, and none serve as a "capital."', 'extras': {'signature': 'EnEKbwERTTIPvLIyi0S9zkfagTh+Xln1iq70yxg6ihF+4s3/hVJkLP6WaM3P8OE4kRJSQrYViWLOn+x+Y4fd4hErC6W96HlWdP6m5MLf/3qoykspSQtEm4fEcgR6ZbJlpMScvghG/EWZfF5oUNYnkvLPKg=='}}]

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-6")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='9611e524-37a5-45af-ae35-d28fa85dd28b'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country or government, so it has no capital city. If you meant the capital letter of the word “Moon,” that would be M. If you meant a fictional setting, tell me which story and I can look up its capital.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 707, 'prompt_tokens': 13, 'total_tokens': 720, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EGpe7fqEQ8R1el0Vu2DGwFQkkjpTu', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a03a0f-6941-7a11-a6b9-9482cddcf555-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 707, 'total_tokens': 720, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital city. If you meant the capital letter of the word “Moon,” that would be M. If you meant a fictional setting, tell me which story and I can look up its capital.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='e7d04007-7e48-477a-88df-534cdc49def7'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='fb3a2969-dba5-4e09-9ae2-b1241582a4e6', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='af5f91f1-eb4e-43d9-adbd-6301f230e59f'),
#               AIMessage(content='Great! Since Luna City is a fictional idea (no real capital exists on the Moon), here’s a detailed worldbuilding concept you can use or adapt.\n\nOverview\n- Luna City is the de facto capital of a nascent lunar colony federation known as the Selenic Union. It sits in a permanently shadowed crater near the equator, chosen for access to ice-rich deposits and sunlight via a ring of solar arrays in crater rims. The city is a layered arcology of domes, tunnels, and skyways, designed to be self-sufficient in water, food, and energy.\n\nSetting and layout\n- Geography: A large crater like a Mare Serenitatis rim location provides natural security and shielding. The central hub, the Core Dome, houses administration, a grand observatory, and public plazas. Outer rings contain housing, farms, and industrial zones.\n- Architecture: Light, modular habitats built with 3D-printed regolith concrete. Vertical layering minimizes drift and dust exposure. Vacuum tunnels connect districts; gravity is standard lunar (1.62 m/s²), but work zones have adjustable gravity for comfort and efficiency.\n- Transport: Mag-lev tubes and small autonomous shuttles zip between districts. Surface rovers handle mining and supply runs; underground freight corridors move large loads with low radiation exposure.\n\nGovernment and society\n- Governing body: The Lunar Sovereignty Assembly (LSA), a democratically elected council with representation from major lunar settlements. An executive Secretary-General runs day-to-day operations, chosen for a fixed term.\n- Law and rights: Open science and water rights are foundational. Citizens have a “Lunar Bill of Resources” that guarantees shelter, food, and education, funded jointly by Earth- lunar partnerships and in-situ resource revenue.\n- Social fabric: Highly collaborative, with a strong culture of scientific merit, innovation, and mutual aid. Education emphasizes life support, robotics, and sustainable farming. The lunar calendar includes “Sol Days” and “Night Weeks” to acknowledge long daylight cycles and local work rhythms.\n\nEconomy and technology\n- Key resources: Water ice extracted from permanently shadowed zones, helium-3 for fusion experiments, basaltic regolith for construction, and solar energy harvested by large ring arrays.\n- Industry: In-situ resource utilization (ISRU) drives construction and life support. 3D-printed machinery, modular housing, and hydroponic farms supply the city.\n- Trade: Luna City exports water-derived commodities, lab results from high-gravity simulations, and clean energy. Imports include advanced microelectronics, Earth-backed currency, and fresh cultural goods from Earth and other colonies.\n- Science and research: A major observatory and a lunar accelerator facility (for physics experiments) anchor the city’s prestige.\n\nCulture and daily life\n- Daily life: People tend to live in small family clusters within modular apartments. Common spaces include community kitchens, shared gardens, and teleport hubs for access to Earth’s digital networks.\n- Education and work: Students rotate through farms, labs, and public works. Many careers blend engineering, biology, and environment design due to the closed-loop systems.\n- Festivals and norms: “Solstice Market” celebrates sunrise along the crater rim; “Dust Night” honors explorers who map uncharted caverns. Art and music reflect a fusion of Earth heritage and lunar frontier practicality.\n- Lifestyle quirks: Low gravity makes long-distance travel effortless; people practice careful movement to conserve energy in suits and gear. Radiation protection and dust management are constant concerns.\n\nHistory and key events (short timeline)\n- 2028–2040: First permanent outpost is established by a coalition of earth-based space agencies and private partners.\n- 2050s: ISRU tech matures; water ice mining becomes commercially viable.\n- 2065: Luna City is founded as the federation’s political and cultural capit ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional concept often used in science fiction as the Moon’s political and cultural capital. Below is a detailed worldbuilding profile you can use as a sandbox for stories, games, or worldbuilding exercises. If you want a different tone (hard sci-fi, cyberpunk, utopian, dystopian, etc.), tell me and I’ll tailor it.
#
# Quick snapshot
# - Name: Luna City
# - Location: South polar region, along the rim of Shackleton Crater and adjacent lava-tube corridors. A mix of surface settlements, subterranean districts, and orbital-adjacent facilities connected by transit tubes.
# - Status: Capital of the Moon (the Moon’s central government and administrative hub for lunar colonies and ISRU operations).
# - Population: Several million residents (roughly 5–12 million depending on era and project cycles), plus rotating workers, researchers, and tourists.
# - Government: A lunar city-state under the Lunar Accord; a city council with a Moon-Earth liaison, a civil service, and a network of semi-autonomous districts. A rotating lunar governor acts as chief executive, elected from the council or assigned by the lunar parliament.
#
# Geography and city layout
# - Core districts:
#   - Government Quarter: The seat of Luna City’s administration, the Lunar Parliament, and the judiciary. Deep under a shielded dome, with sealed archives and ceremonial halls.
#   - Arcology Sectors: Massive multi-use structures that ascend in layers, combining housing, offices, hospitals, and schools. Built to conserve surface space and shield inhabitants from radiation and meteoroids.
#   - Research Basin: A high-tech campus around a stable, well-lit area with shared laboratories, cleanrooms, and ISRU (in-situ resource utilization) facilities. Home to lunar universities and think tanks.
#   - Iceworks District: Access point for water ice mined from permanently shadowed craters, processed into life support, fuel, and industrial uses.
#   - Lunar Port and Transit Spine: A network of radiant transit tunnels and magnetic-levitation (mag-lev) tubes linking Luna City to other moon settlements, presiding over commerce and travel.
#   - Cultural Crescent: The arts, music, museums, and theaters district, featuring glass-timber structures, reflective surfaces to mimic starlight, and a lunar opera house.
# - Terrain and climate: The Moon’s day-night cycle (long days and nights) and vacuum environment require extensive shielding. Luna City concentrates on shielded hubs, with surface modules used mainly for solar farms or viewports during daylight.
#
# History and timeline (condensed)
# - Founding era: Early 22nd century, first permanent base established with seed populations from Earth to test life-sustaining systems, ISRU, and long-term habitation.
# - Ascendancy era: By mid-century, lunar cities expanded, with a formal Lunar Accord creating a shared governance framework and granting “city-state” status to the dominant urban hubs, including Luna City.
# - Golden era: A period of rapid infrastructure growth, surface-to-subsurface expansion, and thriving science, mining, and tourism.
# - Current era: Luna City is the political heart of lunar civilization, balancing Earth governance with local autonomy, resource management, and inter-settlement diplomacy.
#
# Government and politics
# - Structure: A Lunar Parliament (a representative body from districts), a rotating Governor or Mayor (executive), and a lunar judiciary. An Earth-Lunar Authority Forum serves as a liaison with Earth governments and corporate partners.
# - Key principles: Self-governance, resource rights (especially ice and regolith materials), freedom of scientific inquiry, planetary protection, and sustainable colonization.
# - District autonomy: Each district has its own council that handles local services, with oversight from the central government for critical issues like defense, transit safety, and interplanetary commerce.
# - Security: A lunar auxiliary force handles crime prevention, emergency response, and border management between districts; a space and surface defense wing maintains shielding, radiation monitoring, and meteorite defense.
#
# Economy and industry
# - Primary resources: Water ice (for life support and fuel), rare earths and metals from regolith, lunar regolith glass for construction, and solar energy capture from the sunlit zones.
# - Major sectors:
#   - ISRU and manufacturing: Producing propellants, water, oxygen, building materials, and 3D-printed components.
#   - Research and education: Universities and research stations focused on planetary science, biology under low gravity, and robotics.
#   - Tourism and culture: Guided lunar tours, domed architecture tours, observatories, and cultural events in the Cultural Crescent.
#   - Services: Insurance, legal systems, and governance-related services for lunar operations.
# - Currency and trade: A lunar credit system pegged to both Earth-based currencies and a lunar commodity index; trade with Earth-based partners for specialized technology and supplies.
#
# Infrastructure and housing
# - Architecture: A blend of surface-facing domes and subterranean modules. Structures emphasize radiation shielding, micrometeoroid protection, and energy efficiency. Materials include regolith-embedded concrete, aerogel insulation, and laminated glass with heat-control layers.
# - Life support: Closed-loop ecological systems, hydroponics, and compact bioreactors. Waste processing, water recycling, and air regeneration are designed to minimize losses.
# - Transit: A spiderweb of mag-lev tunnels and surface rovers; elevated skyways using low gravity for rapid movement; airless tunnels with airlocks for emergencies. Some districts rely on lunar elevators and tunnel networks.
# - Energy: Solar arrays on crater rims and shielded stations; energy storage in advanced batteries and cryogenic fuels. Some facilities might use compact nuclear microreactors for periods of low sun exposure.
# - Housing: Arcologies (tall, layered habitats) with modular rooms, shared greenhouses, and community spaces. Personal quarters often integrated with smart systems to optimize life support usage.
#
# Science, tech, and education
# - ISRU and material science: Extraction of water ice, processing into fuel and life-support components, and scalable construction materials from lunar regolith.
# - Medicine and biology: Low-gravity medical facilities, telepresence surgery, and pharmaceuticals produced in lunar bioreactors; experiments on how Earth-born biology adapts to lunar living.
# - Robotics and AI: Service robots for maintenance, mining, and health care; autonomy levels range from assistive to fully autonomous in certain sectors.
# - Education: Universities in Luna City focus on space sciences, planetary geology, engineering, and policy. Exchange programs with Earth universities exist to foster cross-planet collaboration.
#
# Daily life and culture
# - Life rhythms: Workers follow shift cycles aligned with lunar day cycles to maximize daylight for solar operations and conserve energy in darkness. Community centers host events during long lunar nights.
# - Cuisine: Food uses hydroponics produce, algae, and preserved Earth imports; lunar dishes emphasize mineral-rich components, with a blending of Earth cuisines adapted to local ingredients.
# - Language and culture: A common lunar creole might emerge, blending Earth languages with space terminology. Cultural life centers around music, sculpture, and astronomy-inspired art.
# - Education for youth: Schools emphasize STEM, ethics of space colonization, and practical life skills for living in closed ecosystems.
#
# Security and resilience
# - Hazards: Meteoroid showers, radiation exposure, and surface roughness. Shielding and redundant life-support systems are standard.
# - Preparedness: Emergency drills, redundant communications, and rapid evacuation routes to subsurface shelters. Civil defense and recovery teams operate 24/7.
# - Diplomacy: Luna City engages in inter-settlement diplomacy, resource-sharing agreements, and earthquake-like crises response coordination with Earth authorities and other lunar settlements.
#
# Notable districts and landmarks
# - The Shield Dome Cluster: A ring of protective domes housing the core administration and archival vaults.
# - The Echo Basin Observatory: A premier observatory for deep-space imaging and solar studies, with a panorama-view deck offering Earth and planetary vistas.
# - Ice Gate Complex: A hub for ice mining operations, processing facilities, and water distribution to the city.
# - The Glass Crescent: A visually striking quarter of transparent or translucent architecture designed to maximize light during the long lunar days and to host cultural events.
# - The Subsurface Garden: A vast underground farm and ecodome that demonstrates a fully closed-loop agricultural system.
# - The Lunar Forum Plaza: A civic space for assemblies, celebrations, and public discourse.
#
# What a typical week might involve
# - Monday: Policy briefings, district meetings, and a public lecture from visiting Earth researchers.
# - Tuesday: Ice operations briefing, water pipeline checks, and maintenance of transit tunnels.
# - Wednesday: Cultural festival in the Cultural Crescent; performance at the lunar opera or a street art exhibit.
# - Thursday: Research presentations at the Research Basin; collaboration talks with Earth space agencies.
# - Friday: Market day in the Lunar Port, trade negotiations with Earth-based partners.
# - Weekend: Public tours of the Ice Gate Complex or a stargazing event at the Echo Basin Observatory.
#
# Story hooks and flavor ideas
# - A governance crisis: A dispute over water rights sparks a political standoff between Luna City and a neighboring lunar settlement.
# - A science mystery: An anomaly in the subsurface ice deposit hints at unknown chemistry or an ancient lunar artifact.
# - A frontier incident: A meteor shower damages transit tubes, forcing a city-wide quarantine and the drama of evacuation.
# - A cultural clash: An Earth-based corporation tries to enforce new environmental rules that conflict with local autonomy and cultural practices.
# - A personal tale: A medic or maintenance worker uncovers a system flaw that could endanger thousands—pulling in ethical and political ramifications.
#
# If you’d like, I can tailor Luna City to a particular vibe:
# - Hard sci-fi: Emphasize plausible tech, ISRU, radiation shielding, and engineering constraints.
# - Cyberpunk: Focus on corporate control, neon-lit dens, and street-level politics.
# - Utopian: A cooperative lunar society with strong citizen participation and open governance.
# - Dystopian: Resource scarcity, social stratification, and surveillance concerns.
#
# Would you like me to adapt Luna City to a specific genre, time period, or set of constraints? If you share your preferred tone, I can rewrite or expand any section to fit your project.
