# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model="gpt-5-nano")

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital. If you’re thinking of a fictional setting, you could name a capital you like (e.g., Lunara, Selene City, Craterport). Want ideas for a sci‑fi lunar capital or a quick note on real lunar governance and missions?

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# In this sci‑fi setting, the Moon’s capital is Selene City, officially Lunaria Prime.
#
# - Location: Nestled on the rim of Shackleton Crater in the Moon’s south polar region. It sits along terraces where a constant sunlit strip meets shadowed floors, ideal for power and life-support systems.
# - Government: The Selenic Confederation’s seat. A Council of Twelve, with a rotating Secretary-General, governs politics, industry, and exploration across the lunar colonies.
# - Population: Roughly 2–3 million residents live and work within a storm of domes, tunnels, and open regolith streets.
# - Architecture and districts:
#   - The Aurora Ring: a ring of solar concentrators and reflective towers that bathe the city in warm light even during lunar night elsewhere.
#   - Crystal Domes: pressure-controlled living complexes carved into the crater rim, made of reinforced basalt glass.
#   - Ice Spine: a vertical water-ice conduit network that houses farms, water processing, and habitat cooling.
#   - The Lumen Market: an open-air, low-gravity bazaar where miners, engineers, and biotechnologists trade tools, minerals, and rare lunar organisms.
# - Economy: Ice mining and water processing from the crater, helium-3 and other volatiles, solar-energy storage, and advanced biotechnology grown in microgravity.
# - Transportation:
#   - Moonrail: a network of sub-surface maglev rails threading through regolith caverns.
#   - Orbital shuttle ports and a high-capacity lunar ascent/descent corridor to LEO.
#   - A few solar-heated air-bridges span crater gaps, with drone taxis for rapid hops.
# - Culture and flavor: The city glows at night with bioluminescent flora in warded parks, concert halls carved from pale basalt, and festivals that celebrate solar cycles, dust storms, and the changing tides of the “sunrise glow” along the rim.
# - Notable landmarks:
#   - The Aurora Arc: a solar-redirecting arc that paints the sky in shifting colors each sol.
#   - The Echo Dome: a cultural venue where holo-narratives are performed within a sound-cavity carved into the inner crater wall.
#   - The Helix Labs: cutting-edge biology and metallurgy labs pushing lunar industry forward.
#
# If you’d prefer a different flavor—another lunar nation with a different capital, or a capital inland away from the south pole—tell me the vibe (grimdark, utopian, corporate rundown, ancient-secrets vibe), and I’ll tailor a fresh version.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunaria

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Selene Prime
# Location: Shackleton Crater, south polar region of the Moon
# Vibe: Icebound metropolis
# Economy: Water-ice mining; helium-3 refinement; lunar manufacturing and logistics

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Selene Prime', location='Lunar south pole, Shackleton Crater rim, in the sunlit annulus around the crater with interconnected ice caverns', vibe='A crystalline, glass-and-ceramic megacity rising in terraces, lit by endless daylight via solar prisms; transit tubes glide between towers as dust settles like powdered starlight.', economy='Ice-water mining, helium-3 extraction, solar energy export, in-situ manufacturing and construction, lunar research, and tourism.')

# %%
response["structured_response"].name
# Out:
# 'Selene Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Selene Prime is a city located at Lunar south pole, Shackleton Crater rim, in the sunlit annulus around the crater with interconnected ice caverns
