# %% [markdown]
# email agent
# - authenticates user
#     - only then are they allowed into the "inbox"
#     - dynamic tools and prompt on the condition of there being an email and password in state that match hardcoded
# - checks "inbox"
#     - email in tool
# - sends emails
#     - human in the loop

# %%
import warnings
warnings.filterwarnings("ignore", message=".*Pydantic serializer warnings.*", category=UserWarning)

from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass

@dataclass
class EmailContext:
    email_address: str = "julie@example.com"
    password: str = "password123"

# %%
from langchain.agents import AgentState

class AuthenticatedState(AgentState):
    authenticated: bool

# %%
from langchain.tools import tool, ToolRuntime
from langgraph.types import Command
from langchain.messages import ToolMessage

@tool
def check_inbox() -> str:
    """Check the inbox for recent emails"""
    return """
    Hi Julie, 
    I'm going to be in town next week and was wondering if we could grab a coffee?
    - best, Jane (jane@example.com)
    """

@tool
def send_email(to: str, subject: str, body: str) -> str:
    """Send an response email"""
    return f"Email sent to {to} with subject {subject} and body {body}"

@tool
def authenticate(email: str, password: str, runtime: ToolRuntime) -> Command:
    """Authenticate the user with the given email and password"""
    if email == runtime.context.email_address and password == runtime.context.password:
        return Command(update={
            "authenticated": True, 
            "messages": [ToolMessage(
                "Successfully authenticated", 
                tool_call_id=runtime.tool_call_id)]
        })
    else:
        return Command(update={
            "authenticated": False,
            "messages": [ToolMessage(
                "Authentication failed", 
                tool_call_id=runtime.tool_call_id)]
        })

# %%
from langchain.agents.middleware import wrap_model_call, ModelRequest, ModelResponse
from typing import Callable

@wrap_model_call
def dynamic_tool_call(request: ModelRequest, 
handler: Callable[[ModelRequest], ModelResponse]) -> ModelResponse:

    """Allow read inbox and send email tools only if user provides correct email and password"""

    authenticated = request.state.get("authenticated")
    
    if authenticated:
        tools = [check_inbox, send_email]
    else:
        tools = [authenticate]

    request = request.override(tools=tools) 
    return handler(request)

# %% [markdown]
# >Note: the prompts were modified since filming to constrain the model to more reliably match the filmed sequence. You may still experience different responses from the model, which is expected. You may need to modify the human message to provide appropriate responses.

# %%
from langchain.agents.middleware import dynamic_prompt

authenticated_prompt = """You are a helpful assistant that can check the inbox and send emails. 
Your first step after authentication is to check the inbox."""
unauthenticated_prompt = "You are a helpful assistant that can authenticate users."

@dynamic_prompt
def dynamic_prompt(request: ModelRequest) -> str:
    """Generate system prompt based on authentication status"""
    authenticated = request.state.get("authenticated")

    if authenticated:
        return authenticated_prompt
    else:
        return unauthenticated_prompt

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver
from langchain.agents.middleware import HumanInTheLoopMiddleware

agent = create_agent(
    "gpt-5-nano",
    tools=[authenticate, check_inbox, send_email],
    checkpointer=InMemorySaver(),
    state_schema=AuthenticatedState,
    context_schema=EmailContext,
    middleware=[
        dynamic_tool_call, 
        dynamic_prompt,
        HumanInTheLoopMiddleware(
            interrupt_on={
                "authenticate": False,
                "check_inbox": False,
                "send_email": True,
            })
        ]
    )

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [HumanMessage(content="julie@example.com, password123")]},
    context=EmailContext(),
    config=config
)

print(response['messages'][-1].content)
# Out:
# I found this email from Jane in your inbox:
#
# Hi Julie,
# I'm going to be in town next week and was wondering if we could grab a coffee?
# - best, Jane (jane@example.com)
#
# Would you like me to reply? I can send a couple of draft options or tailor a message to your style. Here are two quick drafts you can choose from or modify:
#
# Draft A (friendly)
# Subject: Re: Coffee next week?
# Body:
# Hi Jane, that sounds great! I’d love to catch up. I’m free most days next week—what works for you? If you have a preferred time and place, let me know and I’ll meet you there. Looking forward to it!
# - Julie
#
# Draft B (casual)
# Subject: Re: Coffee next week?
# Body:
# Hi Jane! Coffee sounds perfect. What day works for you next week? I’m flexible, so just tell me a good time and place. See you soon—Julie
#
# Options:
# - Tell me which draft you’d like to send, or provide any tweaks (tone, times, or a specific cafe).
# - If you want, I can propose specific times (e.g., Tue/Wed mornings or Thu afternoon) and a neutral meeting spot and send it automatically.
#
# How would you like to proceed?

# %%
response = agent.invoke(
    {"messages": [HumanMessage(content="any draft is fine. don't check back.")]},
    context=EmailContext(),
    config=config
)

print(response['messages'][-1].content)

# %%
print(response['__interrupt__'][0].value['action_requests'][0]['args']['body'])
# Out:
# Hi Jane, that sounds great! I’d love to catch up. I’m free most days next week—what works for you? If you have a preferred time and place, let me know and I’ll meet you there. Looking forward to it!
# - Julie

# %%
from langgraph.types import Command

response = agent.invoke(
    Command( 
        resume={"decisions": [{"type": "approve"}]}  # or "reject"
    ), 
    config=config # Same thread ID to resume the paused conversation
)

print(response["messages"][-1].content)
# Out:
# Email sent to jane@example.com with subject Re: Coffee next week? and body Hi Jane, that sounds great! I’d love to catch up. I’m free most days next week—what works for you? If you have a preferred time and place, let me know and I’ll meet you there. Looking forward to it!
# - Julie
#
# Great, I’ve sent the reply. Would you like me to set a reminder to follow up if you don’t hear back, or keep an eye on the thread for a reply?

# %%
from pprint import pprint

pprint(response)
# Out:
# {'authenticated': True,
#  'messages': [HumanMessage(content='julie@example.com, password123', additional_kwargs={}, response_metadata={}, id='f9f446d2-ed32-4029-8209-9393cfc8c640'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 158, 'prompt_tokens': 151, 'total_tokens': 309, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHgJNUGiQRdxF9VEtDjDjoXIb4XjG', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a04620-7a57-73d0-be49-53a7c59e80a9-0', tool_calls=[{'name': 'authenticate', 'args': {'email': 'julie@example.com', 'password': 'password123'}, 'id': 'call_8zesvm8OJbw4fwIIKqJHBaQ9', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 151, 'output_tokens': 158, 'total_tokens': 309, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}}),
#               ToolMessage(content='Successfully authenticated', name='authenticate', id='f637d7d5-ce1d-4740-984c-f6735a70465b', tool_call_id='call_8zesvm8OJbw4fwIIKqJHBaQ9'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 84, 'prompt_tokens': 219, 'total_tokens': 303, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHgJOPbLOh8oxyzpKhbcGmAuaQswz', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a04620-818a-78f0-804f-95a00d66d9ce-0', tool_calls=[{'name': 'check_inbox', 'args': {}, 'id': 'call_7JXf0B5xvlUkVR8Onshz9xbK', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 219, 'output_tokens': 84, 'total_tokens': 303, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}}),
#               ToolMessage(content="\n    Hi Julie, \n    I'm going to be in town next week and was wondering if we could grab a coffee?\n    - best, Jane (jane@example.com)\n    ", name='check_inbox', id='e173840a-edde-43e4-9097-2264eb22d277', tool_call_id='call_7JXf0B5xvlUkVR8Onshz9xbK'),
#               AIMessage(content="I found this email from Jane in your inbox:\n\nHi Julie, \nI'm going to be in town next week and was wondering if we could grab a coffee?\n- best, Jane (jane@example.com)\n\nWould you like me to reply? I can send a couple of draft options or tailor a message to your style. Here are two quick drafts you can choose from or modify:\n\nDraft A (friendly)\nSubject: Re: Coffee next week?\nBody:\nHi Jane, that sounds great! I’d love to catch up. I’m free most days next week—what works for you? If you have a preferred time and place, let me know and I’ll meet you there. Looking forward to it! \n- Julie\n\nDraft B (casual)\nSubject: Re: Coffee next week?\nBody:\nHi Jane! Coffee sounds perfect. What day works for you next week? I’m flexible, so just tell me a good time and place. See you soon—Julie\n\nOptions:\n- Tell me which draft you’d like to send, or provide any tweaks (tone, times, or a specific cafe).\n- If you want, I can propose specific times (e.g., Tue/Wed mornings or Thu afternoon) and a neutral meeting spot and send it automatically.\n\nHow would you like to proceed?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1233, 'prompt_tokens': 282, 'total_tokens': 1515, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 960, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHgJQnkAMnAmjU1gAPhdx49OPdGtU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a04620-86df-7bb3-83c6-153f3d0eae2f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 282, 'output_tokens': 1233, 'total_tokens': 1515, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 960}}),
#               HumanMessage(content="any draft is fine. don't check back.", additional_kwargs={}, response_metadata={}, id='cae1e2ad-5468-4443-b2d0-f9b95350cef8'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 732, 'prompt_tokens': 565, 'total_tokens': 1297, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHgJtHGGmdlrHizb7epv7LdLvjD2E', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a04620-f7a9-7ba0-acf0-f0c2f02d1a8a-0', tool_calls=[{'name': 'send_email', 'args': {'to': 'jane@example.com', 'subject': 'Re: Coffee next week?', 'body': 'Hi Jane, that sounds great! I’d love to catch up. I’m free most days next week—what works for you? If you have a preferred time and place, let me know and I’ll meet you there. Looking forward to it!\n- Julie'}, 'id': 'call_SmPHAGuJVU7BC66uSjrBwF4x', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 565, 'output_tokens': 732, 'total_tokens': 1297, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#               ToolMessage(content='Email sent to jane@example.com with subject Re: Coffee next week? and body Hi Jane, that sounds great! I’d love to catch up. I’m free most days next week—what works for you? If you have a preferred time and place, let me know and I’ll meet you there. Looking forward to it!\n- Julie', name='send_email', id='dc296342-cd72-4a73-b927-66cecb2d783e', tool_call_id='call_SmPHAGuJVU7BC66uSjrBwF4x'),
#               AIMessage(content='Email sent to jane@example.com with subject Re: Coffee next week? and body Hi Jane, that sounds great! I’d love to catch up. I’m free most days next week—what works for you? If you have a preferred time and place, let me know and I’ll meet you there. Looking forward to it!\n- Julie\n\nGreat, I’ve sent the reply. Would you like me to set a reminder to follow up if you don’t hear back, or keep an eye on the thread for a reply?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 110, 'prompt_tokens': 731, 'total_tokens': 841, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EHgKFOV6UGeahtqcyCeZjySMZYdVy', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a04621-4e83-7c63-ac3c-9c5595c18857-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 731, 'output_tokens': 110, 'total_tokens': 841, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
